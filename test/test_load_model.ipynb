# %%
from gensim.models import Word2Vec

model = Word2Vec.load('../data/300/wiki_model')

# %%
test_words = ['金融','上','股票','跌','经济','可以']
for i in range(len(test_words)):
    res = model.most_similar(test_words[i])
    print (test_words[i])
    print (res)
# Out:
# 金融
# [('国际金融', 0.6972329616546631), ('金融市场', 0.6634346842765808), ('金融业', 0.6613123416900635), ('银行业', 0.6575241088867188), ('金融服务', 0.641120433807373), ('保险业', 0.6403008699417114), ('金融业务', 0.6289265751838684), ('证券市场', 0.6261496543884277), ('信贷', 0.6128036379814148), ('金融体系', 0.6005113124847412)]
# 上
# [('上以', 0.6393406391143799), ('上能', 0.620512068271637), ('上要', 0.5981729030609131), ('之上', 0.5927760601043701), ('上会', 0.5856289267539978), ('上仅', 0.5848206281661987), ('上时', 0.5811234712600708), ('上用', 0.5551722049713135), ('上均', 0.5331511497497559), ('上于', 0.5178389549255371)]
# 股票
# [('公司股票', 0.7635475397109985), ('股票交易', 0.7089259624481201), ('股价', 0.7028743028640747), ('股票市场', 0.6885484457015991), ('普通股', 0.686585545539856), ('证券', 0.6819421648979187), ('A股', 0.678008496761322), ('股市', 0.6673222780227661), ('期货', 0.6613224744796753), ('证券市场', 0.6609508991241455)]
# 跌
# ...

# %%
# Out:
# [-6.71988583e+00 -1.30129108e+01 -3.96710277e+00 -3.01994181e+00
#  -1.18680391e+01 -8.42732430e+00 -2.27673302e+01  6.82307959e-01
#   2.33637619e+01  7.77517700e+00 -1.15083084e+01  6.09541607e+00
#   1.91763294e+00 -1.85629101e+01  1.14992237e+01 -1.32028961e+01
#  -1.80058632e+01 -2.53055692e+00 -1.08411574e+00  2.35622311e+01
#   4.37286472e+00 -7.15673637e+00 -5.86203448e-02 -3.74696236e+01
#  -1.19161682e+01 -1.31208858e+01 -4.31918192e+00  1.93459682e+01
#   1.73775845e+01  1.57051444e+00 -1.48390532e+01 -1.73954654e+00
#   7.99485922e+00 -3.89656425e-01  4.37446451e+00 -4.43264198e+00
#  -3.24340391e+00 -4.49483566e+01  6.92732430e+00 -1.85721409e+00
#   5.67706203e+00  1.85082912e+01 -1.17531538e+00 -4.31792885e-01
#  -1.32330523e+01 -2.74329281e+00  1.37059488e+01 -1.37287560e+01
#  -7.17023075e-01  2.03456298e-01  1.97080002e+01 -1.14617014e+01
#  -1.14483571e+00 -2.36312413e+00  8.75600338e+00  1.22363305e+00
# ...
